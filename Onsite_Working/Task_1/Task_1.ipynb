# %%
import pandas as pd
import numpy as np

# %%
file_path = "Task_1.csv"
df = pd.read_csv(file_path)

# %%
df
# Out:
#   Patient ID     Patient Name Date of Birth Service Date  Procedure Code  \
# 0      P1001    Emily Johnson    1985-02-14   2023-09-10           99213
# 1      P1002    Michael Smith    1978-06-22   2023-09-12           80053
# 2      P1003  Sophia Martinez    1990-11-05   2023-09-15           93000
# 3      P1004    William Brown    1969-04-30   2023-09-18           74177
# 4      P1005     Olivia Davis    1982-09-17   2023-09-20           20550
# 5      P1006     James Wilson    1995-12-08   2023-09-22           93010
# 6      P1007  Isabella Garcia    1975-07-19   2023-09-25           71020
# 7      P1008  Benjamin Miller    1988-03-27   2023-09-28           90658
# 8      P1009    Mia Rodriguez    2000-08-14   2023-09-30           85025
# 9      P1010    Alexander Lee    1960-01-05   2023-10-02           93005
#
#            Procedure Description  Billing Amount Insurance Provider  \
# 0                   Office Visit           150.0         HealthPlus
# ...

# %%
{
    "account_number": "Patient_ID",
    "service_date": "Service_Date",
    "debtor": {
        "first_name": "Patient_Name",
        "last_name": "Patient_Name",
        "middle_name": "Patient_Name",
        "date_of_birth": "Date_of_Birth",
    },
    "responsible_person": {
        
    },
    "procedure_code": "procedure_code",
    "procedure_description":"",
    "initial_account_balance": "billing amount",
    "current_account_balance": "billing amount",
    "amount_paid_to_date": "initial_account_balance - current_account_balance",
    "insurance":{
        "insurance_provider": "Insurance_Company",
        "policy_number": "Insurance_Policy_Number",
    }
}
